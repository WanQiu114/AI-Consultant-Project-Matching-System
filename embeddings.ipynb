# %%
import pandas as pd
import numpy as np
import joblib
from sentence_transformers import SentenceTransformer

# Load candidate data
personnel_df = pd.read_csv("data_pro.csv")

# Initialize SentenceTransformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

def generate_candidate_embeddings(df):
    """
    Generate embeddings for each candidate based on their skills, experience, name, and country.
    """
    print("Generating embeddings for candidates...")
    embeddings = []

    for idx, row in df.iterrows():
        # Ensure aggregated_skill is a list
        skills_list = row['aggregated_skill'] if isinstance(row['aggregated_skill'], list) else []

        # Handle missing or empty values
        name = row['name'] if pd.notnull(row['name']) else "Unknown Name"
        experience_years = row['experience_years'] if pd.notnull(row['experience_years']) else 0
        country = row['country'] if pd.notnull(row['country']) else "Unknown Country"

        # Construct text for embedding
        candidate_text = f"Name: {name}, Skills: {', '.join(skills_list)}, Experience: {experience_years} years, Country: {country}."
        embeddings.append(model.encode(candidate_text))

        # Log progress
        if idx % 100 == 0:
            print(f"Processed {idx+1}/{len(df)} candidates...")

    print(f"Generated embeddings for {len(df)} candidates.")
    return np.array(embeddings)

def build_knn_index(candidate_embeddings, n_neighbors=50):
    """
    Build a KNN index for candidate embeddings.
    """
    print("Building KNN index...")
    from sklearn.neighbors import NearestNeighbors
    knn = NearestNeighbors(n_neighbors=n_neighbors, metric='cosine')
    knn.fit(candidate_embeddings)
    print("KNN index built.")
    return knn

def save_knn_index(knn, filename="knn_index.joblib"):
    """
    Save the KNN index to a file.
    """
    print("Saving KNN index...")
    joblib.dump(knn, filename)
    print(f"KNN index saved to {filename}.")

def save_embeddings(candidate_embeddings, candidate_ids, embeddings_file="embeddings.npy", ids_file="candidate_ids.npy"):
    """
    Save embeddings and candidate IDs.
    """
    print("Saving embeddings and IDs...")
    np.save(embeddings_file, candidate_embeddings)
    np.save(ids_file, candidate_ids)
    print(f"Embeddings saved to {embeddings_file}.")
    print(f"Candidate IDs saved to {ids_file}.")

# Generate embeddings
candidate_embeddings = generate_candidate_embeddings(personnel_df)
candidate_ids = personnel_df["person_id"].values

# Build KNN index
knn = build_knn_index(candidate_embeddings, n_neighbors=50)

# Save embeddings and KNN index
save_embeddings(candidate_embeddings, candidate_ids)
save_knn_index(knn)
# Out:
# /Users/saikiranpilli/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Generating embeddings for candidates...
# Processed 1/18293 candidates...
# Processed 101/18293 candidates...
# Processed 201/18293 candidates...
# Processed 301/18293 candidates...
# Processed 401/18293 candidates...
# Processed 501/18293 candidates...
# Processed 601/18293 candidates...
# Processed 701/18293 candidates...
# Processed 801/18293 candidates...
# Processed 901/18293 candidates...
# Processed 1001/18293 candidates...
# Processed 1101/18293 candidates...
# Processed 1201/18293 candidates...
# Processed 1301/18293 candidates...
# Processed 1401/18293 candidates...
# Processed 1501/18293 candidates...
# Processed 1601/18293 candidates...
# Processed 1701/18293 candidates...
# Processed 1801/18293 candidates...
# Processed 1901/18293 candidates...
# Processed 2001/18293 candidates...
# Processed 2101/18293 candidates...
# Processed 2201/18293 candidates...
# Processed 2301/18293 candidates...
# Processed 2401/18293 candidates...
# Processed 2501/18293 candidates...
# Processed 2601/18293 candidates...
# Processed 2701/18293 candidates...
# Processed 2801/18293 candidates...
# Processed 2901/18293 candidates...
# Processed 3001/18293 candidates...
# Processed 3101/18293 candidates...
# Processed 3201/18293 candidates...
# Processed 3301/18293 candidates...
# Processed 3401/18293 candidates...
# Processed 3501/18293 candidates...
# Processed 3601/18293 candidates...
# Processed 3701/18293 candidates...
# Processed 3801/18293 candidates...
# Processed 3901/18293 candidates...
# Processed 4001/18293 candidates...
# Processed 4101/18293 candidates...
# Processed 4201/18293 candidates...
# Processed 4301/18293 candidates...
# Processed 4401/18293 candidates...
# Processed 4501/18293 candidates...
# Processed 4601/18293 candidates...
# Processed 4701/18293 candidates...
# Processed 4801/18293 candidates...
# Processed 4901/18293 candidates...
# Processed 5001/18293 candidates...
# Processed 5101/18293 candidates...
# Processed 5201/18293 candidates...
# Processed 5301/18293 candidates...
# Processed 5401/18293 candidates...
# Processed 5501/18293 candidates...
# Processed 5601/18293 candidates...
# Processed 5701/18293 candidates...
# Processed 5801/18293 candidates...
# Processed 5901/18293 candidates...
# Processed 6001/18293 candidates...
# Processed 6101/18293 candidates...
# Processed 6201/18293 candidates...
# Processed 6301/18293 candidates...
# Processed 6401/18293 candidates...
# Processed 6501/18293 candidates...
# Processed 6601/18293 candidates...
# Processed 6701/18293 candidates...
# Processed 6801/18293 candidates...
# Processed 6901/18293 candidates...
# Processed 7001/18293 candidates...
# Processed 7101/18293 candidates...
# Processed 7201/18293 candidates...
# Processed 7301/18293 candidates...
# Processed 7401/18293 candidates...
# Processed 7501/18293 candidates...
# Processed 7601/18293 candidates...
# Processed 7701/18293 candidates...
# Processed 7801/18293 candidates...
# Processed 7901/18293 candidates...
# Processed 8001/18293 candidates...
# Processed 8101/18293 candidates...
# Processed 8201/18293 candidates...
# Processed 8301/18293 candidates...
# Processed 8401/18293 candidates...
# Processed 8501/18293 candidates...
# Processed 8601/18293 candidates...
# Processed 8701/18293 candidates...
# Processed 8801/18293 candidates...
# Processed 8901/18293 candidates...
# Processed 9001/18293 candidates...
# Processed 9101/18293 candidates...
# Processed 9201/18293 candidates...
# Processed 9301/18293 candidates...
# Processed 9401/18293 candidates...
# Processed 9501/18293 candidates...
# Processed 9601/18293 candidates...
# Processed 9701/18293 candidates...
# Processed 9801/18293 candidates...
# Processed 9901/18293 candidates...
# Processed 10001/18293 candidates...
# Processed 10101/18293 candidates...
# Processed 10201/18293 candidates...
# Processed 10301/18293 candidates...
# Processed 10401/18293 candidates...
# Processed 10501/18293 candidates...
# Processed 10601/18293 candidates...
# Processed 10701/18293 candidates...
# Processed 10801/18293 candidates...
# Processed 10901/18293 candidates...
# Processed 11001/18293 candidates...
# Processed 11101/18293 candidates...
# Processed 11201/18293 candidates...
# Processed 11301/18293 candidates...
# Processed 11401/18293 candidates...
# Processed 11501/18293 candidates...
# Processed 11601/18293 candidates...
# Processed 11701/18293 candidates...
# Processed 11801/18293 candidates...
# Processed 11901/18293 candidates...
# Processed 12001/18293 candidates...
# Processed 12101/18293 candidates...
# Processed 12201/18293 candidates...
# Processed 12301/18293 candidates...
# Processed 12401/18293 candidates...
# Processed 12501/18293 candidates...
# Processed 12601/18293 candidates...
# Processed 12701/18293 candidates...
# Processed 12801/18293 candidates...
# Processed 12901/18293 candidates...
# Processed 13001/18293 candidates...
# Processed 13101/18293 candidates...
# Processed 13201/18293 candidates...
# Processed 13301/18293 candidates...
# Processed 13401/18293 candidates...
# Processed 13501/18293 candidates...
# Processed 13601/18293 candidates...
# Processed 13701/18293 candidates...
# Processed 13801/18293 candidates...
# Processed 13901/18293 candidates...
# Processed 14001/18293 candidates...
# Processed 14101/18293 candidates...
# Processed 14201/18293 candidates...
# Processed 14301/18293 candidates...
# Processed 14401/18293 candidates...
# Processed 14501/18293 candidates...
# Processed 14601/18293 candidates...
# Processed 14701/18293 candidates...
# Processed 14801/18293 candidates...
# Processed 14901/18293 candidates...
# Processed 15001/18293 candidates...
# Processed 15101/18293 candidates...
# Processed 15201/18293 candidates...
# Processed 15301/18293 candidates...
# Processed 15401/18293 candidates...
# Processed 15501/18293 candidates...
# Processed 15601/18293 candidates...
# Processed 15701/18293 candidates...
# Processed 15801/18293 candidates...
# Processed 15901/18293 candidates...
# Processed 16001/18293 candidates...
# Processed 16101/18293 candidates...
# Processed 16201/18293 candidates...
# Processed 16301/18293 candidates...
# Processed 16401/18293 candidates...
# Processed 16501/18293 candidates...
# Processed 16601/18293 candidates...
# Processed 16701/18293 candidates...
# Processed 16801/18293 candidates...
# Processed 16901/18293 candidates...
# Processed 17001/18293 candidates...
# Processed 17101/18293 candidates...
# Processed 17201/18293 candidates...
# Processed 17301/18293 candidates...
# Processed 17401/18293 candidates...
# Processed 17501/18293 candidates...
# Processed 17601/18293 candidates...
# Processed 17701/18293 candidates...
# Processed 17801/18293 candidates...
# Processed 17901/18293 candidates...
# Processed 18001/18293 candidates...
# Processed 18101/18293 candidates...
# Processed 18201/18293 candidates...
# Generated embeddings for 18293 candidates.
# Building KNN index...
# KNN index built.
# Saving embeddings and IDs...
# Embeddings saved to embeddings.npy.
# Candidate IDs saved to candidate_ids.npy.
# Saving KNN index...
# KNN index saved to knn_index.joblib.
