# %%
import pandas as pd
import numpy as np
import joblib
from sentence_transformers import SentenceTransformer

# Load pre-saved embeddings, candidate IDs, and KNN index
candidate_embeddings = np.load("embeddings.npy")
candidate_ids = np.load("candidate_ids.npy")
knn = joblib.load("knn_index.joblib")

# Load personnel data
personnel_df = pd.read_csv("candiate_data.csv")

# Initialize SentenceTransformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

def parse_roles(roles):
    """
    Parse roles, generate embeddings, and structure role requirements.
    """
    role_embeddings = []
    for role in roles:
        role_text = f"Role: {role['role']}, Skills: {', '.join(role.get('skills', []))}, " \
                    f"Location: {role.get('location', 'Anywhere')}, Experience: {role.get('experience', 'Not Specified')}."
        embedding = model.encode(role_text)
        role_embeddings.append({
            "role": role['role'],
            "embedding": embedding,
            "skills": role.get('skills', []),
            "location": role.get('location', 'Anywhere'),
            "experience": role.get('experience', None),
            "quantity": role.get('quantity', 1)
        })
    return role_embeddings

def calculate_match_score(candidate, role, similarity, weight_similarity=0.9, weight_experience=0.1):
    """
    Calculate a match score based on similarity and experience.
    """
    experience_years = candidate['experience_years']
    return weight_similarity * similarity + weight_experience * experience_years

def match_roles_to_candidates(roles, knn, candidate_embeddings, candidate_ids, top_k=50):
    """
    Match roles to candidates based on role embeddings and similarity to candidate embeddings.
    """
    matches = []
    for role in roles:
        print(f"Matching candidates for role: {role['role']}...")
        role_vector = np.array(role["embedding"]).reshape(1, -1)
        distances, indices = knn.kneighbors(role_vector, n_neighbors=top_k)

        candidates = []
        for i, idx in enumerate(indices[0]):
            candidate_id = candidate_ids[idx]
            similarity = 1 - distances[0][i]  # Cosine similarity: 1 - distance

            candidate_row = personnel_df[personnel_df['person_id'] == candidate_id].iloc[0]
            
            # Handle remote roles (no location restriction)
            role_location = role['location'].strip().lower()

            if role_location != "anywhere" and role_location != "remote" and role_location not in candidate_row['country'].strip().lower():
                # Skip this candidate if location doesn't match (and role isn't remote)
                continue 
            
            # Calculate match score
            score = calculate_match_score(candidate_row, role, similarity)
            candidates.append({
                "person_id": candidate_id,
                "name": candidate_row['name'],
                "similarity": similarity,
                "experience_years": candidate_row['experience_years'],
                "skills": candidate_row['aggregated_skill'],
                "score": score
            })

        # Sort and take top matches
        candidates = sorted(candidates, key=lambda x: -x['score']) 
        matches.append({
            "role": role['role'],
            "candidates": candidates[:role["quantity"]] 
        })

        print(f"Found {len(candidates)} matches for role: {role['role']}.")

    return matches

# Example input for roles
roles_input = [
    {"role": "AI Researcher", "skills": ["Python", "Deep Learning", "TensorFlow"], "location": "United States", "experience": "3+", "quantity": 1},
    {"role": "Database Administrator", "skills": ["SQL", "Oracle"], "location": "India", "experience": "4+", "quantity": 2},
    {"role": "Remote Software Engineer", "skills": ["Java", "Spring"], "location": "Remote", "experience": "5+", "quantity": 3},
    {"role": "Data Scientist", "skills": ["Python", "Machine Learning"], "location": "Canada", "experience": "4+", "quantity": 1}
]

# Parse roles and match candidates
parsed_roles = parse_roles(roles_input)
matches = match_roles_to_candidates(parsed_roles, knn, candidate_embeddings, candidate_ids)

# Display results
for match in matches:
    print(f"Role: {match['role']}")
    for candidate in match['candidates']:
        print(f"  - Candidate ID: {candidate['person_id']}, Score: {candidate['score']:.4f}")
        print(f"    Skills: {candidate['skills']}")
        print('\n')
# Out:
# /Users/saikiranpilli/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Matching candidates for role: AI Researcher...
# Found 44 matches for role: AI Researcher.
# Matching candidates for role: Database Administrator...
# Found 17 matches for role: Database Administrator.
# Matching candidates for role: Remote Software Engineer...
# Found 50 matches for role: Remote Software Engineer.
# Matching candidates for role: Data Scientist...
# Found 9 matches for role: Data Scientist.
# Role: AI Researcher
#   - Candidate ID: 17544, Score: 4.0270
#     Skills: ['Developed novel software to score the traffic sources', 'Assisted in developing a visualization system', 'Worked towards developing a clustering algorithm for astronomical objects', 'Contributed in developing a Linux based multithreaded program debugger']['Python', 'express.js', 'async', 'node.js', 'Python', 'NumPy', 'SciPy', 'C', 'OpenMP']
#
#
# Role: Database Administrator
#   - Candidate ID: 2622, Score: 4.0540
#     Skills: ['Oracle Database Administration', 'Oracle Goldengate', 'Data Guard', 'RMAN', 'Oracle Enterprise Manager', 'Backup and Recovery', 'Disaster Recovery', 'Database Tuning', 'Informatica ETL', 'Database Development']['Oracle 12c', 'ASM', 'Performance Parameters', 'Cluster Installation', 'Patching', 'Oracle Goldengate', 'Data Guard', 'RMAN', 'Oracle Enterprise Manager', 'Backup and Recovery', 'Disaster Recovery', 'Oracle 10g/11g', 'OEM 12c Cloud Control', 'RMAN', 'Data Guard', 'Informatica ETL', 'Database Tuning', 'Oracle 9i/8i', 'Solaris', 'RMAN', 'SQL*Loader', 'Database Administration', 'Database Development']
#
#
#   - Candidate ID: 3028, Score: 4.0338
#     Skills: ['Database Administration', 'Database Development', 'Data Scraping', 'Data Analysis', 'Performance Tuning', 'Disaster Recovery', 'Database Migration', 'Database Upgrade', 'Database Patching']['Oracle', 'SQL Server', 'Postgres', 'Mongo Databases', 'MySQL', 'Oracle', 'Python', 'R', 'SAS', 'Tableau', 'Oracle', 'Progress', 'Shell Scripting', 'RMAN']
#
#
# Role: Remote Software Engineer
#   - Candidate ID: 14089, Score: 4.6133
#     Skills: ['Data analysis', 'Data recovery', 'Embedded Platforms', 'HTML', 'CSS', 'Latex', 'XML', 'VB.NET', 'ASP.NET', 'Android Studio', 'JavaScript', 'Java', 'Dart', 'Flutter', 'Cache', 'PDL', 'Bootstrap', 'SQL', 'Anypoint Studio MuleSoft', 'Linux', 'Windows', 'SQL Server Management System', 'GIT', 'Hyper V Manager', 'Postman', 'Fiddler', 'Android Studio', 'TFS', 'IBM Rational', 'JIRA', 'Visio', 'Eclipse', 'SQL Developer', 'HealthShare', 'Visual Studio', 'HealthConnect', 'WordPress', 'SquareSpace', 'Requirement and data analysis', 'Management information systems', 'Data recovery and data collocation analysis', 'Agile Scrum']['Spring boot', 'Spring JPA', 'Hibernate', 'Ant', 'Maven', 'Gradle', 'MySQL', 'SQL Oracle', 'Agile Scrum', 'Jenkins', 'Weblogic', 'GIT', 'Rational', 'Intersystems HealthShare', 'Android App Development', 'Java', 'Dart', 'Flutter', 'Espresso', '.NET', 'Web Application', 'Student Database Management System', 'API Documentation', 'Web Development', 'Data Analysis']
#
#
#   - Candidate ID: 13561, Score: 4.0971
#     Skills: ['JAVA ENDUR DEVELOPER', 'Coding in primarily Java', 'Conversion and verification of converted production scripts from AVS to JVS', 'Identified, analyzed and verified production artifacts and log files to enable the transition to be transparently smooth for development and support', 'Worked with test framework owner to enable challenging scripts to run in framework after unit testing', 'Updated on-boarding and "how to" documents', 'Completed complex coding tasks in primarily C#', 'Assisted with and tested Windows based to .Net core conversion running in containers on Linux', 'Participated in onsite testing of client systems', 'Managed testing and test cases using TestRail', 'Using NUnit for unit-testing framework', 'Hands-on management of complex code builds', 'Built and deployed software applications to various environments daily', 'Was considered and provided the highest level of internal support for complex build problems, release and environment issues involving debugging of code in C, C++, C#, Java and others', 'Completed migration of code base to new Visual Studio platforms and .Net versions', 'Worked with industry standard tools for code coverage and analysis, debugging, performance profiling and memory management including Purify and Coverity', 'Collaborated directly with third-party companies to resolve issues integrating their products and tools for use in our environment', 'Was responsible for being on-call for emergency or high-level situations, writing deployment scripts, debugging applications and evaluating new technologies', 'Experienced with financial and energy market software', 'Worked on application software development and testing in C/C++ environment', 'Maintained and improved upon automated regression testing suite to prevent the introduction of errors into the release cycle saving time and expenses', 'Maintained and developed build environments across multiple platforms including Windows, UNIX, VM/CMS, VMS, USS and Z/OS', 'Responsible for porting production systems from one language to another including conversions to/from Perl, Korn shell, C, and Rexx', 'Created detailed system documentation and provided all coverage for the internal build group support hotline', 'Oversaw assisting other programmers with creation of new sources and modules, deletion of de-supported code and associated cleanup from the source management system']['JAVA', 'ENDUR DEVELOPER', 'C#', '.Net core', 'Windows', 'Linux', 'NUnit', 'C', 'C++', 'C#', 'Java', 'Visual Studio', '.Net', 'Purify', 'Coverity', 'C/C++', 'Perl', 'Korn shell', 'Rexx']
#
#
#   - Candidate ID: 13958, Score: 3.5972
#     Skills: ['Java', 'J2EE', 'Servlets', 'JSP', 'JDBC', 'Hibernate', 'JMS', 'XML', 'Spring Framework', 'Microservices', 'Git', 'MongoDB', 'SQL', 'PL/SQL', 'Maven', 'JUnit', 'Mockito', 'Sonar', 'Jenkins', 'UML', 'SOAP', 'REST Web Services', 'ANT', 'WebLogic', 'Agile']['Java', 'J2EE', 'Servlets', 'JSP', 'JDBC', 'Spring JDBC Template', 'Hibernate', 'JMS', 'XML', 'Spring Framework', 'Spring MVC', 'Spring IOC', 'Spring JDBC', 'Spring AOP', 'Spring Boot', 'Spring Cloud', 'Microservices', 'Git', 'SVN', 'GitHub', 'Bitbucket', 'Gitlab', 'MongoDB', 'Apache Tomcat', 'WebLogic', 'WebSphere', 'JBoss', 'SQL', 'PL/SQL', 'Maven', 'Ant', 'JUnit', 'Mockito', 'Sonar', 'Jenkins', 'Java', 'J2EE', 'JSP', 'HTML', 'CSS', 'JavaScript', 'jQuery', 'XML', 'Hibernate', 'Spring', 'MVC', 'UML', 'MySQL', 'PL/SQL', 'Stored Procedures', 'JMS', 'SOAP', 'REST Web Services', 'ANT', 'Apache Tomcat', 'UNIX', 'SVN', 'WebSphere', 'Agile', 'Java', 'JSP', 'WebLogic Server', 'DB2', 'JDBC', 'JavaScript', 'Servlets', 'MVC', 'JavaBeans', 'Maven', 'JUnit', 'Agile']
#
#
# Role: Data Scientist
#   - Candidate ID: 8381, Score: 3.9136
#     Skills: ['leadership', 'problem solving', 'resourcefulness', 'innovation', 'strategic thinking', 'sports']['data entry', 'data collection', 'client management', 'data scanning', 'data entry clerk training', 'data progress reporting', 'computer maintenance', 'hardware installation', 'accounting', 'record keeping', 'technical support', 'field visits', 'staff management', 'client communication', 'database management']

# %%
import pandas as pd
import numpy as np
import joblib
from sentence_transformers import SentenceTransformer

# Load pre-saved embeddings, candidate IDs, and KNN index
candidate_embeddings = np.load("embeddings.npy")
candidate_ids = np.load("candidate_ids.npy")
knn = joblib.load("knn_index.joblib")

# Load personnel data
personnel_df = pd.read_csv("candiate_data.csv")

# Initialize SentenceTransformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

def parse_roles(roles):
    """
    Parse roles, generate embeddings, and structure role requirements.
    """
    role_embeddings = []
    for role in roles:
        role_text = f"Role: {role['role']}, Skills: {', '.join(role.get('skills', []))}, " \
                    f"Location: {role.get('location', 'Anywhere')}, Experience: {role.get('experience', 'Not Specified')}."
        embedding = model.encode(role_text)
        role_embeddings.append({
            "role": role['role'],
            "embedding": embedding,
            "skills": role.get('skills', []),
            "location": role.get('location', 'Anywhere'),
            "experience": role.get('experience', None),
            "quantity": role.get('quantity', 1)
        })
    return role_embeddings

def calculate_match_score(candidate, role, similarity, weight_similarity=0.9, weight_experience=0.1):
    """
    Calculate a match score based on similarity and experience.
    """
    experience_years = candidate['experience_years']
    return weight_similarity * similarity + weight_experience * experience_years

def match_roles_to_candidates(roles, knn, candidate_embeddings, candidate_ids, top_k=50):
    """
    Match roles to candidates based on role embeddings and similarity to candidate embeddings.
    """
    matches = []
    for role in roles:
        print(f"Matching candidates for role: {role['role']}...")
        role_vector = np.array(role["embedding"]).reshape(1, -1)
        distances, indices = knn.kneighbors(role_vector, n_neighbors=top_k)

        candidates = []
        for i, idx in enumerate(indices[0]):
            candidate_id = candidate_ids[idx]
            similarity = 1 - distances[0][i]  # Cosine similarity: 1 - distance

            candidate_row = personnel_df[personnel_df['person_id'] == candidate_id].iloc[0]
            
            # Handle remote roles (no location restriction)
            role_location = role['location'].strip().lower()

            if role_location != "anywhere" and role_location != "remote" and role_location not in candidate_row['country'].strip().lower():
                # Skip this candidate if location doesn't match (and role isn't remote)
                continue 
            
            # Calculate match score
            score = calculate_match_score(candidate_row, role, similarity)
            candidates.append({
                "person_id": candidate_id,
                "name": candidate_row['name'],
                "similarity": similarity,
                "experience_years": candidate_row['experience_years'],
                "skills": candidate_row['aggregated_skill'],
                "score": score
            })

        # Sort and take top matches
        candidates = sorted(candidates, key=lambda x: -x['score']) 
        matches.append({
            "role": role['role'],
            "candidates": candidates[:role["quantity"]] 
        })

        print(f"Found {len(candidates)} matches for role: {role['role']}.")

    return matches

# Example input for roles
roles_input =  [
    {
      "role": "Mobile App Developer",
      "skills": [
        "iOS Development",
        "Android Development",
        "Biometric Authentication"
      ],
      "location": "Remote",
      "experience": "3-5 years",
      "quantity": 10
    },
    {
      "role": "Backend Developer",
      "skills": [
        "Node.js",
        "Database Management",
        "API Development"
      ],
      "location": "Remote",
      "experience": "3-5 years",
      "quantity": 2
    },
    {
      "role": "UI/UX Designer",
      "skills": [
        "Mobile App Design",
        "User Experience",
        "Prototyping"
      ],
      "location": "Remote",
      "experience": "2-4 years",
      "quantity": 1
    },
    {
      "role": "QA Engineer",
      "skills": [
        "Mobile App Testing",
        "Security Testing",
        "Automated Testing"
      ],
      "location": "Remote",
      "experience": "2-4 years",
      "quantity": 2
    },
    {
      "role": "Security Specialist",
      "skills": [
        "App Security",
        "Encryption Protocols",
        "Penetration Testing"
      ],
      "location": "Remote",
      "experience": "5-7 years",
      "quantity": 1
    },
    {
      "role": "Project Manager",
      "skills": [
        "Agile Methodologies",
        "Team Coordination",
        "Banking Regulations"
      ],
      "location": "Remote",
      "experience": "5-7 years",
      "quantity": 1
    }
  ]


# Parse roles and match candidates
parsed_roles = parse_roles(roles_input)
matches = match_roles_to_candidates(parsed_roles, knn, candidate_embeddings, candidate_ids)

# Display results
for match in matches:
    print(f"Role: {match['role']}")
    for candidate in match['candidates']:
        print(f"  - Candidate ID: {candidate['person_id']}, Score: {candidate['score']:.4f}, Experience: {candidate['experience_years']} years")
        print(f"    Skills: {candidate['skills']}")
        print('\n')
# Out:
# /Users/saikiranpilli/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Matching candidates for role: Mobile App Developer...
# Found 50 matches for role: Mobile App Developer.
# Matching candidates for role: Backend Developer...
# Found 50 matches for role: Backend Developer.
# Matching candidates for role: UI/UX Designer...
# Found 50 matches for role: UI/UX Designer.
# Matching candidates for role: QA Engineer...
# Found 50 matches for role: QA Engineer.
# Matching candidates for role: Security Specialist...
# Found 50 matches for role: Security Specialist.
# Matching candidates for role: Project Manager...
# Found 50 matches for role: Project Manager.
# Role: Mobile App Developer
#   - Candidate ID: 3728, Score: 4.5235, Experience: 39.0 years
#     Skills: ['Content management', 'Git', 'Html', 'Javascript', 'Bootstrap', 'Css', 'Sass', 'Content management system', 'jquery', 'Processor']['Interfaced directly with the client', 'Assisted with wireframing of designs', 'Wrote HTML and CSS', 'Led gathering of the requirements', 'Checked codebase and tested the software', 'Designed the frontend of their internal website', 'Created the website from the ground up', 'Implemented Bootstrap CSS framework', 'Used Bower and Composer to debug existing code', 'Used Circle CI for Continuous Integration testing', 'Designed UI/UX and built a customized website using WordPress template', 'Implemented enhancements in various widgets using JavaScript', 'Responsible for web hosting, MySQL Database Management, and upholding SEO best practices', 'Integrated Google Analytics and Google Maps API', 'Increased website traffic by up to 70% in less than 6 months', 'Utilized A/B testing to identify strong marketing strategies', 'Created websites using Content Management Systems, Wix and WordPress', 'Coded PHP snippets to create customized Content Management Websites', 'Worked with Adobe Photoshop to convert PSD files to create dynamic web pages', 'Integrated SEO and Google Analytics to efficiently target users and increase traffic', 'Tracked projects using Asana and Zoho for better management']
#
#
#   - Candidate ID: 12433, Score: 4.5129, Experience: 39.0 years
#     Skills: ['Software Design', 'Development', 'Maintenance', 'Requirements Gathering', 'Analysis', 'Design', 'Development', 'Testing', 'Deployment', 'Maintenance', 'Waterfall', 'Agile/Scrum', 'Android Applications', 'Google Play Store', 'Real Devices', 'Geny Motion', 'Android Virtual Device', 'Memory Leaks', 'Push Notifications', 'Multiple Screen Support', 'Data Offline Usage', 'Audio Features', 'Video Features', 'Graphic Design', 'Animation', 'Bluetooth', 'Location', 'Camera', 'Notifications', 'Maps', 'Android UI Toolkit', 'Layout Managers', 'Web Service Protocols', 'Hybrid-app', 'Phonegap', 'Google Maps API', 'Geocoder API', 'Core Java', 'Struts', 'Spring', 'Web Services', 'Hibernate', 'EJB', 'JSP', 'Servlets', 'JDBC', 'RMI', 'JNDI', 'SOAP', 'HTTP GET', 'HTTP POST', 'Java Applet', 'Servlets', 'JSP', 'AJAX', 'JavaScript', 'HTML', 'CSS3', 'Collections', 'Multi-Threading', 'Socket-Programming', 'Exception Handling', 'Android Components', 'Async Task', 'Threads', 'Services', 'Localization', 'SVN', 'GIT', 'UNIX/LINUX', 'XML', 'XSLT', 'XML Schema', 'Oracle', 'SQLite', 'MySQL', 'Communication', 'Analytical', 'Problem Solving']['Android SDK', 'Eclipse IDE', 'Android Studio', 'SQL', 'SQLite', 'Java', 'XML', 'JSON', 'Waterfall', 'Agile/Scrum', 'Android Frameworks', 'Android UI Toolkit', 'Web Service Protocols', 'Google Maps API', 'Geocoder API', 'Core Java', 'Struts', 'Spring', 'Web Services', 'Hibernate', 'EJB', 'JSP', 'Servlets', 'JDBC', 'RMI', 'JNDI', 'SOAP', 'HTTP', 'Java Applet', 'AJAX', 'JavaScript', 'HTML', 'CSS3', 'Android Components', 'Async Task', 'Threads', 'Services', 'SVN', 'GIT', 'UNIX/LINUX', 'XML', 'XSLT', 'XML Schema', 'Oracle', 'SQLite', 'MySQL', 'Android SDK', 'TextViews', 'Buttons', 'Check boxes', 'Alert dialogs', 'Actionbar', 'Spinners', 'Content providers', 'Content resolver', 'AsyncTask', 'AlertDialog', 'Restful Web service', 'JSON', 'AJAX', 'JSON Parser', 'XMLPullParser', 'DOM parser', 'Web Views', 'Facebook API', 'Google Analytics', 'Cache', 'Crashlytics', 'Java', 'XML', 'JSON', 'Ajax', 'JQuery', 'Genymotion', 'Postman', 'Stash', 'JIRA', 'Android SDK', 'Java', 'XML', 'RESTful', 'JSON', 'Android Studio', 'Git', 'GSON', 'Fragments', 'Action Bar', 'Custom Dialog Boxes', 'Android SDK', 'Fragments', 'Android Bluetooth', 'Android Location Connectivity', 'Logcat', 'DDMS', 'Trace view', 'DOM parser', 'RESTful web services', 'JSON', 'List views', 'GIT', 'SQLite', 'Servlets', 'Java Server Pages (JSPs)', 'XML schema', 'SAX', 'DOM', 'SOA', 'JDBC', 'Tomcat', 'Oracle', 'Agile', 'Scrum', 'Java', 'JavaScript', 'HTML', 'CSS', 'SQL', 'J2EE', 'Rational Application Developer 7.0']
#
#
#   - Candidate ID: 17490, Score: 4.4431, Experience: 38.0 years
#     Skills: ['Web and Mobile Application Development', 'ReactJS', 'ReactMobile', 'Tensorflow', 'LSTM', 'AI', 'Predictive Analysis', 'Geospatial Algorithms', 'PostGIS', 'ArcGIS', 'Python', 'Content Maturity Metric', 'Raster to Vector Conversion', 'BUA Detection', 'Load Balancing', 'Network Python Development', 'Multi-VRF', 'Android', 'RESTful Web Application', 'HTML5', 'Bootstrap', 'JQuery', 'PHP', 'JavaScript', 'Intel Edison', 'AWS IoT', 'Amazon S3', 'Network Virtualization', 'Security Analysis', 'Penetration Testing', 'NoSQL', 'Neo4j', 'InfiniteGraph', 'Gephi', 'Twitter', 'Sentiment Analysis', 'Bayesian AI', 'MySQL', 'MS SQL Server', 'MarkLogic', 'Spatial Data', 'Android', 'JSON', 'SQLite', 'Threading', 'WFIT Radio', 'Git', 'Ruby on Rails']['ReactJS', 'ReactMobile', 'Tensorflow', 'LSTM', 'AI', 'Predictive Analysis', 'PostGIS', 'ArcGIS', 'Python', 'Content Maturity Metric', 'Raster to Vector Conversion', 'BUA Detection', 'Load Balancing', 'Python', 'Multi-VRF', 'Android', 'RESTful Web Application', 'HTML5', 'Bootstrap', 'JQuery', 'PHP', 'JavaScript', 'Intel Edison', 'AWS IoT', 'Amazon S3', 'Network Virtualization', 'Security Analysis', 'Penetration Testing', 'NoSQL', 'Neo4j', 'InfiniteGraph', 'Gephi', 'Twitter', 'Sentiment Analysis', 'Bayesian AI', 'MySQL', 'MS SQL Server', 'MarkLogic', 'Spatial Data', 'Android', 'JSON', 'SQLite', 'Threading', 'WFIT Radio', 'Git', 'Ruby on Rails']
#
#
#   - Candidate ID: 14321, Score: 4.1384, Experience: 35.0 years
#     Skills: ['Android Application Development', 'Java Development', 'C++', 'SQL', 'REST API', 'JSON', 'Agile', 'Scrum', 'MVC', 'MVP', 'MVVM', 'Shared Preferences', 'Google Maps API', 'SQLite', 'HTML', 'JavaScript', 'CSS', 'J2EE', 'EJB', 'UML', 'JDBC', 'JBoss', 'Maven', 'Oracle']['Android SDK', 'Java', 'Eclipse', 'Android NDK', 'C++', 'SQLite', 'REST API', 'JSON', 'GCM', 'Agile', 'Scrum', 'Android Studio', 'Java', 'Agile', 'Scrum', 'AIDL', 'Retrofit', 'REST', 'JIRA', 'Jenkins', 'Bitbucket', 'Android SDK', 'Java', 'Eclipse', 'Google Maps API', 'Shared Preferences', 'Fragments', 'JSON', 'SQLite', 'HTML', 'JavaScript', 'CSS', 'J2EE', 'HTML', 'JSP', 'CSS', 'DHTML', 'EJB', 'JSP Custom Tags', 'JavaScript', 'Eclipse', 'UML', 'JDBC', 'JBoss', 'Maven', 'Oracle']
#
#
#   - Candidate ID: 14045, Score: 3.6200, Experience: 30.0 years
#     Skills: ['Seamless Mainframe Management', 'Application Development', 'Prototype Design', 'Workflow Coordination', 'End-to-End Testing', 'Technical Documentation', 'Feature Enhancement', 'Code Optimization', 'Data Visualization', 'ETL Workflow']['IBM Mainframe', 'Visio Workflow Plans', 'Java', 'PL/SQL', 'Estimation Engine', 'Project Planning', 'Business Requirements Analysis', 'Technical Solutions', 'Project Management', 'Requirements Gathering', 'Stakeholder Communication', 'Data Dashboards', 'Microstrategy', 'Informatica', 'Tableau', 'Power BI']
#
#
#   - Candidate ID: 13740, Score: 3.4496, Experience: 28.0 years
#     Skills: ['software engineer', 'team management', 'client communication', 'solution implementation', 'development flow', 'home page implementation', 'artist details page implementation', 'map locations and customization', 'festival information', 'notifications', 'directions', 'video management', 'VIPER and MVP architecture', 'Agile method', 'continuous integration', 'UI/UX design', 'checkout process implementation', 'Apple Pay', 'Apple Wallet', 'VisaCheckout', 'Paypal', 'Notification', 'checkout.com', 'certificates and provisioning profiles creation', 'store location feature implementation', 'delivery options management', 'app navigation']['Swift', 'Xcode', 'Objective-C', 'C', 'ReactNative', 'Java', 'Javascript', 'TypeScript', 'SQL', 'MongoDB', 'Cassandra', 'Android', 'Android Studio', 'Java', 'Spring framework', 'JSP', 'SQL', 'Angular']
#
#
#   - Candidate ID: 13888, Score: 3.3119, Experience: 27.0 years
#     Skills: ['Services developer', 'Java/J2EE', 'Spring Boot', 'Spring MVC', 'ReactJS', 'ReduxJS', 'HTML5', 'JavaScript', 'CSS3', 'Node.JS', 'Waterfall', 'Agile', 'Document Object Model (DOM)', 'Single page applications (SPA)', 'CSS preprocessors', 'Rest Microservices', 'SQL', 'PL/SQL', 'Project Management Methodologies', 'Software Estimation Methodologies', 'Web Services', 'SOAP', 'REST', 'Cucumber', 'JUnit', 'Jasmine', 'Karma', 'JMeter', 'IBM - RTC', 'GIT', 'Analysis', 'Design', 'Implementation', 'Testing', 'Enhancement', 'Production Support', 'Change Management', 'Angular 2', 'Salesforce', 'Spring Batch', 'Ionic 2', 'TypeScript']['Java', 'J2EE', 'Spring Boot', 'Spring MVC', 'ReactJS', 'ReduxJS', 'jQuery', 'HTML', 'JavaScript', 'CSS', 'Node.JS', 'Waterfall', 'Agile', 'ReactJS', 'HTML5', 'JavaScript', 'CSS3', 'jQuery', 'CSS LESS', 'Bootstrap', 'AJAX', 'Document Object Model (DOM)', 'DOM Functions', 'Single page applications (SPA)', 'CSS preprocessors', 'LESS', 'SASS', 'GulpJS', 'Rest Microservices', 'Spring Boot', 'SQL', 'PL/SQL', 'Oracle', 'MYSQL', 'DB2', 'Project Management Methodologies', 'Software Estimation Methodologies', 'Project Planning', 'Tracking', 'Execution', 'Resource Management', 'Risk Management', 'Web Services', 'SOAP', 'REST', 'Cucumber', 'JUnit', 'Jasmine', 'Karma', 'JMeter', 'IBM - RTC', 'GIT', 'Analysis', 'Design', 'Implementation', 'Testing', 'Enhancement', 'Production Support', 'Change Management', 'Angular 2', 'SOAP', 'RESTful Web services', 'Ps framework', 'JavaScript', 'GulpJS', 'es6', 'Spring Batch', 'Salesforce', 'RESTful Web service', 'Ionic 2', 'Angular 2', 'TypeScript', 'scss', 'Manatee-scanner', 'Velocify']
#
#
#   - Candidate ID: 4920, Score: 3.1096, Experience: 25.0 years
#     Skills: ['Packaging', 'Shipping', 'Mentor', 'Printers', 'Technical Support', 'Database', 'Networking', 'Security', 'Business Management', 'Merchandising', 'Inventory', 'Cash Handling', 'Javascript', 'HTML', 'Linux', 'Cloud Formation', 'Cloud Automation', 'App Development', 'Block Storage', 'Computing', 'Network', 'Database', 'Cloud Security', 'AWS Networking', 'Cloud Security', 'Public Cloud']['Scrum Master', 'Agile Methodologies', 'Servant Leader', 'Ceremonies', 'Daily Stand-ups', 'Backlog Refinement', 'Sprint Planning', 'Team Demos', 'Retrospecting', 'Camp Events Planning', 'Camper Monitoring', 'Incident Reporting', 'Emergency Procedures', 'Camp Rules Enforcement', 'Carton Preparation', 'Container Inspection', 'Improper Package Identification', 'Shipping Tools Usage', 'Teamwork', 'Customer Assistance', 'Inventory Management', 'Merchandising', 'Cash Handling', 'Printer Maintenance', 'Computer Maintenance', 'Technical Support', 'Schedule Management', 'Mail Review', 'Mail Sorting', 'Barcode Verification', 'Heavy Equipment Handling', 'Mail Truck Loading', 'Call Handling', 'Relationship Building', 'Sales Meetings', 'Event Booking', 'Organizational Skills', 'Multitasking']
#
#
#   - Candidate ID: 5566, Score: 3.0647, Experience: 24.43805612594113 years
#     Skills: ['iOS development', 'AI', 'Machine learning', 'Data analysis', 'Teaching', 'Lesson planning', 'Student engagement', 'Grading', 'Python', 'Data processing', 'Unit testing', 'Refactoring', 'HTML', 'CSS', 'JavaScript', 'Angular', 'API development', 'DevOps automation', 'Java', 'Data visualization']['iOS development', 'AI', 'Machine learning', 'Data analysis', 'iOS development', 'AI', 'Machine learning', 'Data analysis', 'Teaching', 'Lesson planning', 'Student engagement', 'Grading', 'Python', 'Data processing', 'Unit testing', 'Refactoring', 'HTML', 'CSS', 'JavaScript', 'Angular', 'API development', 'DevOps automation', 'HTML', 'CSS', 'AngularJS', 'Java', 'Data visualization']
#
#
#   - Candidate ID: 14322, Score: 2.7447, Experience: 21.0 years
#     Skills: ['Android Application Development', 'Java Development', 'Agile Methodology', 'REST API Integration', 'JSON Parsing', 'Google Maps Integration', 'SQLite Database', 'UI/UX Design', 'Notification Management', 'Multithreading']['Android SDK', 'Java', 'Eclipse', 'SQLite', 'REST API', 'JSON', 'Google Maps API', 'Android SDK', 'Java', 'Agile', 'AIDL', 'Retrofit', 'REST services', 'Custom Android system', 'UI framework', 'Android SDK', 'Java', 'Google Maps API', 'Implicit Intent Functions', 'Shared Preferences', 'Notification Manager', 'REST', 'JSON', 'J2EE', 'HTML', 'JSP', 'CSS', 'DHTML', 'EJB', 'JSP Custom Tags', 'JavaScript', 'JDBC', 'JBoss', 'Maven', 'Oracle']
#
#
# Role: Backend Developer
#   - Candidate ID: 3486, Score: 4.2853, Experience: 37.0 years
#     Skills: ['Front-End Web Developer', 'UI/UX', 'Writing well tested code', 'Scaling', 'Fast running', 'Readable code', 'Authorized to work in the US']['HTML', 'CSS', 'JavaScript', 'Bootstrap', 'Photoshop', 'XML', 'JavaScript', 'HTML', 'CSS', 'jQuery', 'Angular', 'Bootstrap', 'Microsoft Azure', 'Microsoft Team Foundation Server', 'GIT', 'HTML', 'CSS', 'Illustrator', 'Photoshop']
#
#
#   - Candidate ID: 5563, Score: 4.2796, Experience: 37.0 years
#     Skills: ['Versatile Front End Developer', 'experienced in designing, developing and maintaining complex apps that drive business growth', 'Authorized to work in the US for any employer', 'Tank Commander']['Bootstrap', 'Php', 'jquery', 'Restful services', 'Front End', 'Javascript', 'Angular', 'React', 'Angularjs', 'Java', 'HTML5', 'CSS3', 'Node.js', 'Spring Framework', 'Bootstrap', 'Php', 'jquery', 'Restful services', 'Front End', 'Javascript', 'Angular', 'React', 'Angularjs', 'Java', 'HTML5', 'CSS3', 'Node.js', 'Spring Framework', 'Bootstrap', 'Php', 'jquery', 'Restful services', 'Front End', 'Javascript', 'Angular', 'React', 'Angularjs', 'Java', 'HTML5', 'CSS3', 'Node.js', 'Spring Framework']
#
#
# Role: UI/UX Designer
#   - Candidate ID: 17490, Score: 4.4017, Experience: 38.0 years
#     Skills: ['Web and Mobile Application Development', 'ReactJS', 'ReactMobile', 'Tensorflow', 'LSTM', 'AI', 'Predictive Analysis', 'Geospatial Algorithms', 'PostGIS', 'ArcGIS', 'Python', 'Content Maturity Metric', 'Raster to Vector Conversion', 'BUA Detection', 'Load Balancing', 'Network Python Development', 'Multi-VRF', 'Android', 'RESTful Web Application', 'HTML5', 'Bootstrap', 'JQuery', 'PHP', 'JavaScript', 'Intel Edison', 'AWS IoT', 'Amazon S3', 'Network Virtualization', 'Security Analysis', 'Penetration Testing', 'NoSQL', 'Neo4j', 'InfiniteGraph', 'Gephi', 'Twitter', 'Sentiment Analysis', 'Bayesian AI', 'MySQL', 'MS SQL Server', 'MarkLogic', 'Spatial Data', 'Android', 'JSON', 'SQLite', 'Threading', 'WFIT Radio', 'Git', 'Ruby on Rails']['ReactJS', 'ReactMobile', 'Tensorflow', 'LSTM', 'AI', 'Predictive Analysis', 'PostGIS', 'ArcGIS', 'Python', 'Content Maturity Metric', 'Raster to Vector Conversion', 'BUA Detection', 'Load Balancing', 'Python', 'Multi-VRF', 'Android', 'RESTful Web Application', 'HTML5', 'Bootstrap', 'JQuery', 'PHP', 'JavaScript', 'Intel Edison', 'AWS IoT', 'Amazon S3', 'Network Virtualization', 'Security Analysis', 'Penetration Testing', 'NoSQL', 'Neo4j', 'InfiniteGraph', 'Gephi', 'Twitter', 'Sentiment Analysis', 'Bayesian AI', 'MySQL', 'MS SQL Server', 'MarkLogic', 'Spatial Data', 'Android', 'JSON', 'SQLite', 'Threading', 'WFIT Radio', 'Git', 'Ruby on Rails']
#
#
# Role: QA Engineer
#   - Candidate ID: 11391, Score: 4.4211, Experience: 39.0 years
#     Skills: ['IT Quality Assurance', 'Customer Service', 'Real Estate', 'Detail Oriented', 'Finance/Investing', 'Cyber Security']['IT Quality Assurance', 'Troubleshooting', 'Agile Development', 'HP Application Life-cycle Management', 'Sabre Mainframe(FOS)', 'XML', 'Standard Operating Procedures', 'Risk-based Security Screening', 'Screening Equipment Operation', 'Threat Identification', 'Crisis Management', 'Client Service', 'System Test and Support', 'Credit Card Processing', 'Root Cause Analysis', 'Process Improvement', 'Real Estate', 'Market Analysis', 'Contract Writing', 'Law Enforcement Observation', 'Incident Reporting']
#
#
#   - Candidate ID: 17490, Score: 4.3292, Experience: 38.0 years
#     Skills: ['Web and Mobile Application Development', 'ReactJS', 'ReactMobile', 'Tensorflow', 'LSTM', 'AI', 'Predictive Analysis', 'Geospatial Algorithms', 'PostGIS', 'ArcGIS', 'Python', 'Content Maturity Metric', 'Raster to Vector Conversion', 'BUA Detection', 'Load Balancing', 'Network Python Development', 'Multi-VRF', 'Android', 'RESTful Web Application', 'HTML5', 'Bootstrap', 'JQuery', 'PHP', 'JavaScript', 'Intel Edison', 'AWS IoT', 'Amazon S3', 'Network Virtualization', 'Security Analysis', 'Penetration Testing', 'NoSQL', 'Neo4j', 'InfiniteGraph', 'Gephi', 'Twitter', 'Sentiment Analysis', 'Bayesian AI', 'MySQL', 'MS SQL Server', 'MarkLogic', 'Spatial Data', 'Android', 'JSON', 'SQLite', 'Threading', 'WFIT Radio', 'Git', 'Ruby on Rails']['ReactJS', 'ReactMobile', 'Tensorflow', 'LSTM', 'AI', 'Predictive Analysis', 'PostGIS', 'ArcGIS', 'Python', 'Content Maturity Metric', 'Raster to Vector Conversion', 'BUA Detection', 'Load Balancing', 'Python', 'Multi-VRF', 'Android', 'RESTful Web Application', 'HTML5', 'Bootstrap', 'JQuery', 'PHP', 'JavaScript', 'Intel Edison', 'AWS IoT', 'Amazon S3', 'Network Virtualization', 'Security Analysis', 'Penetration Testing', 'NoSQL', 'Neo4j', 'InfiniteGraph', 'Gephi', 'Twitter', 'Sentiment Analysis', 'Bayesian AI', 'MySQL', 'MS SQL Server', 'MarkLogic', 'Spatial Data', 'Android', 'JSON', 'SQLite', 'Threading', 'WFIT Radio', 'Git', 'Ruby on Rails']
#
#
# Role: Security Specialist
#   - Candidate ID: 10068, Score: 4.2697, Experience: 36.0 years
#     Skills: ['Peoplesoft', 'Sap', 'R/3', 'Active directory', 'Remedy', 'Workday', 'Oracle', 'Training', 'Ordering', 'Managing projects', 'Remedy and Service now systems', 'Office 365', 'Oracle/Oblix', 'PeopleSoft', 'Workday', 'Active Directory (AD)', 'SAP R/3 Production', 'SAP Net Weaver', 'SCORE/SOMS', 'Agile methodology', 'CyberArk', 'Training teams', 'Technical and security skills']['Access control', 'Troubleshooting', 'Access management', 'Provisioning workflow', 'Performance metrics', 'IAM processes', 'Controls', 'Communication', 'Standard Operating Procedures', 'Auditing', 'Reporting', 'User ID management', 'Remediating', 'Mitigating controls gaps', 'UAT', 'Production integrations', 'Access control', 'Onboarding', 'Offboarding', 'Team management', 'System administration', 'Access requests', 'Access changes', 'Termination requests', 'Audit guidelines', 'Reporting', 'Training', 'Incident resolution', 'Data gathering', 'Hypothesis development', 'Solution development', 'Guidance to junior team members', 'Continuous improvement', 'User account creation', 'User account editing', 'User account disabling', 'User access management', 'User roles', 'Risk analysis', 'Home directory management', 'Active Directory', 'Security groups', 'Distribution lists', 'Audit guidelines']
#
#
# Role: Project Manager
#   - Candidate ID: 8648, Score: 4.6168, Experience: 40.0 years
#     Skills: ['Agile Project Management', 'ITIL', 'Software Development Life Cycle', 'Scrum Practices', 'Project Planning', 'Continuous Improvements', 'Client Relationship Management', 'Agile Development Practices', 'Process Improvement', 'Documentation', 'SLA Management', 'Technical Support', 'Requirements Analysis', 'Project Coordination']['Agile Project Management', 'ITIL', 'Software Development Life Cycle', 'Scrum Practices', 'Project Planning', 'Continuous Improvements', 'Client Relationship Management', 'Agile Development Practices', 'SDLC', 'Process Improvement', 'Documentation', 'SLA Management', 'Technical Support', 'Software Development', 'Requirements Analysis', 'Project Coordination']
